# %% [markdown]
# # Tools for downloading data from the MinIO server hosted @uvA-TCE
#
# #### 1. Login with your MinIO account and password
#
# ![image.png](attachment:9d784630-43c9-4f8f-b561-322c6a70c714.png)
#
# #### 2. Select the folder you want to download your files to
#
# ![image.png](attachment:075edb80-7b9e-4c2d-a9eb-957ae9bee5fd.png)
#
# #### 3. Select the Bucket, then select and download the objects.
#
# ![image.png](attachment:c3d24463-ef8d-4146-b24f-4e83e35dd433.png)
#
# - Single click and move your mouse to select multiple objects
# - Click `Back` to go back to the previous level folder
# - Click `Save Selection` to save your current selection of objects, this allows you to download files from multiple folders, e.g., PVOL files of several days.
# - Click `Download` to start downloading files.

# %%
import tcedata as td
td.get_files_from_minio()
